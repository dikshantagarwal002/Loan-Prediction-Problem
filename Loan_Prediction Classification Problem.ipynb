# %%
import pandas as pd
import numpy as np
df_train = pd.read_csv('train_u6lujuX_CVtuZ9i.csv')
df_train.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
df_test = pd.read_csv('test_Y3wMUE5_7gLdaTN.csv')
df_test.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
y = df_train.loc[:,['Loan_Status']].values.ravel()

# %%
df_train = df_train.drop('Loan_Status', axis =1)
df= df_train.append(df_test)
df = df.drop('Loan_ID', axis=1).reset_index(drop=True)
df.tail()
# Out:
#     Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 976   Male     Yes         3+  Not Graduate           Yes             4009
# 977   Male     Yes          0      Graduate            No             4158
# 978   Male      No          0      Graduate            No             3250
# 979   Male     Yes          0      Graduate            No             5000
# 980   Male      No          0      Graduate           Yes             9200
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 976             1777.0       113.0             360.0             1.0
# 977              709.0       115.0             360.0             1.0
# 978             1993.0       126.0             360.0             NaN
# 979             2393.0       158.0             360.0             1.0
# 980                0.0        98.0             180.0             1.0
#
#     Property_Area
# 976         Urban
# 977         Urban
# 978     Semiurban
# 979         Rural
# ...

# %%
df.isnull().sum()
# Out:
# Gender               24
# Married               3
# Dependents           25
# Education             0
# Self_Employed        55
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           27
# Loan_Amount_Term     20
# Credit_History       79
# Property_Area         0
# dtype: int64

# %%
df.Gender= df.Gender.fillna('Male')
df.Married= df.Married.fillna('Yes')
df.Dependents= df.Dependents.fillna(0)
df.Self_Employed= df.Self_Employed.fillna('No')
df.LoanAmount= df.LoanAmount.fillna(df.LoanAmount.mean())
df.Loan_Amount_Term= df.Loan_Amount_Term.fillna(360)
df.Credit_History= df.Credit_History.fillna(1)
df.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
df.Credit_History = df.Credit_History.astype(str)
df['Total_Income']= df['ApplicantIncome']+df['CoapplicantIncome']
df = pd.get_dummies(df)
df.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0   142.51153             360.0
# 1             4583             1508.0   128.00000             360.0
# 2             3000                0.0    66.00000             360.0
# 3             2583             2358.0   120.00000             360.0
# 4             6000                0.0   141.00000             360.0
#
#    Total_Income  Gender_Female  Gender_Male  Married_No  Married_Yes  \
# 0        5849.0              0            1           1            0
# 1        6091.0              0            1           0            1
# 2        3000.0              0            1           0            1
# 3        4941.0              0            1           0            1
# 4        6000.0              0            1           1            0
#
#    Dependents_0         ...           Dependents_3+  Education_Graduate  \
# ...

# %%
from sklearn.preprocessing import scale,MinMaxScaler
from sklearn.decomposition import PCA,NMF
scaler = MinMaxScaler()
scaler.fit(df)
df_scaled = scaler.transform(df)
pca = NMF()
pca.fit(df_scaled)
df_scaled = pca.transform(df_scaled)
X = df_scaled[:614,:]
val = df_scaled[614:, :]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC

# %%
n_knn = np.arange(1,50)
param_grid_knn = {'n_neighbors': n_knn}
knn = KNeighborsClassifier()
knn_cv = GridSearchCV(knn, param_grid_knn, cv = 5)
knn_cv.fit(X,y)
print(knn_cv.best_score_)
print(knn_cv.best_params_)
# Out:
# 0.7833876221498371
# {'n_neighbors': 9}

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
c_logreg = np.logspace(-5, 5)
param_grid_logreg = {'C': c_logreg}
logreg = LogisticRegression()
logreg_cv = GridSearchCV(logreg, param_grid_logreg, cv=5)
logreg_cv.fit(X, y)
print(logreg_cv.best_score_)
print(logreg_cv.best_params_)
# Out:
# 0.8094462540716613
# {'C': 0.30888435964774846}

# %%
max_features_dt = np.arange(5,12)
min_samples_leaf_dt = np.linspace(0.05,0.2,10)
param_grid_dt = {
    'max_features': max_features_dt, 'min_samples_leaf': min_samples_leaf_dt
}
dt = DecisionTreeClassifier()
dt_cv=GridSearchCV(dt, param_grid_dt, cv=5)
dt_cv.fit(X,y)
print(dt_cv.best_score_)
print(dt_cv.best_params_)
# Out:
# 0.8029315960912052
# {'max_features': 11, 'min_samples_leaf': 0.06666666666666668}

# %%
max_features_rf = ['log2','auto','sqrt']
n_estimators_rf = [5,15,30]
min_samples_leaf_rf = np.arange(5,26, 5)
param_grid_rf = {'max_features':max_features_rf, 'n_estimators':n_estimators_rf, 'min_samples_leaf':min_samples_leaf_rf}
rf = RandomForestClassifier()
rf_cv = GridSearchCV(rf, param_grid_rf, cv=5)
rf_cv.fit(X,y)
print(rf_cv.best_score_)
print(rf_cv.best_params_)
# Out:
# 0.8045602605863192
# {'max_features': 'sqrt', 'min_samples_leaf': 25, 'n_estimators': 30}

# %%
learning_rate_gb = [0.05, 0.1, 0.15, 0.2]
max_features_gb = np.arange(2,6,2)
min_samples_leaf_gb = np.arange(5,16,5)
param_grid_gb = {'learning_rate': learning_rate_gb, 'max_features':max_features_gb, 'min_samples_leaf': min_samples_leaf_gb}
gb= GradientBoostingClassifier()
gb_cv = GridSearchCV(gb, param_grid_gb, cv=5)
gb_cv.fit(X,y)
print(gb_cv.best_score_)
print(gb_cv.best_params_)
# Out:
# 0.7964169381107492
# {'learning_rate': 0.05, 'max_features': 2, 'min_samples_leaf': 15}

# %%
output = logreg_cv.predict(val)
df_output = pd.DataFrame()
df_output['Loan_ID'] = df_test['Loan_ID']
df_output['Loan_Status'] = output
df_output.to_csv('output.csv',index=False)
